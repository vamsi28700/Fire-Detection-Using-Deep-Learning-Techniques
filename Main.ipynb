# %%
# !pip install pip --upgrade
# Out:
# Requirement already satisfied: pip in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (21.2.4)
# Collecting pip
#   Downloading pip-21.3.1-py3-none-any.whl (1.7 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-21.3.1

# %%
# !pip install tensorflow --upgrade
# Out:
# Requirement already satisfied: tensorflow in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (1.14.0)
# Collecting tensorflow
#   Downloading tensorflow-2.7.0-cp37-cp37m-win_amd64.whl (430.8 MB)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (1.1.2)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.6.0-cp37-cp37m-win_amd64.whl (2.8 MB)
# Collecting gast<0.5.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (3.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (1.36.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (1.12.1)
# Collecting keras<2.8,>=2.7.0rc0
#   Downloading keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# Collecting tensorflow-estimator<2.8,~=2.7.0rc0
#   Downloading tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.21.0
#   Downloading tensorflow_io_gcs_filesystem-0.22.0-cp37-cp37m-win_amd64.whl (1.5 MB)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (0.13.0)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting libclang>=9.0.1
#   Downloading libclang-12.0.0-py2.py3-none-win_amd64.whl (13.1 MB)
# Collecting flatbuffers<3.0,>=1.12
#   Downloading flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (1.21.2)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorflow) (1.16.0)
# Collecting tensorboard~=2.6
#   Downloading tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# Collecting cached-property
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.26.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.33.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from tensorboard~=2.6->tensorflow) (58.0.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\krishna vamsi\anaconda3\envs\tensorenv\lib\site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.6.0)
# Installing collected packages: requests-oauthlib, tensorboard-plugin-wit, tensorboard-data-server, google-auth-oauthlib, cached-property, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard, opt-einsum, libclang, keras, h5py, google-pasta, gast, flatbuffers, astunparse, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 1.14.0
#     Uninstalling tensorflow-estimator-1.14.0:
#       Successfully uninstalled tensorflow-estimator-1.14.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Attempting uninstall: keras
#     Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
#   Attempting uninstall: h5py
#     Found existing installation: h5py 2.8.0
#     Uninstalling h5py-2.8.0:
#       Successfully uninstalled h5py-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.2
#     Uninstalling gast-0.5.2:
#       Successfully uninstalled gast-0.5.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# Successfully installed astunparse-1.6.3 cached-property-1.5.2 flatbuffers-2.0 gast-0.4.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 h5py-3.6.0 keras-2.7.0 libclang-12.0.0 opt-einsum-3.3.0 requests-oauthlib-1.3.0 tensorboard-2.7.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.7.0 tensorflow-estimator-2.7.0 tensorflow-io-gcs-filesystem-0.22.0

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.7.0

# %%
import cv2
import numpy as np
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image
#Load the saved model
model = tf.keras.models.load_model('C:/Users/Krishna Vamsi/Desktop/4-1 courses/4th project/InceptionV3.h5')
video = cv2.VideoCapture(0)
while True:
        _, frame = video.read()

        im = Image.fromarray(frame, 'RGB')
        im = im.resize((224,224))
        img_array = image.img_to_array(im)
        img_array = np.expand_dims(img_array, axis=0) / 255
        probabilities = model.predict(img_array)[0]
        
        prediction = np.argmax(probabilities)
        
        if prediction == 0:
                frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
                print(probabilities[prediction])
        cv2.imshow("Capturing", frame)
        key=cv2.waitKey(1)
        if key == ord('q'):
            break
video.release()
cv2.destroyAllWindows()
# Out:
# 0.5740103
# 0.5451121
# 0.5784701
# 0.5128589
# 0.61638683
# 0.5199959
# 0.59430474
# 0.5190133
# 0.80520034
# 0.8327005
# 0.77493703
# 0.64356804
# 0.7182784
# 0.54990375
# 0.6528488
# 0.63625157
# 0.71715033
# 0.6530383
# 0.6531517
# 0.5412932
# 0.5329305
# 0.5498366
# 0.51867986
# 0.52480626
# 0.62928116
# 0.5753555
# 0.5128558
# 0.50033516
# 0.66339487
# 0.51973885
# 0.5702948
# 0.51812696
# 0.55701
# 0.54187065
# 0.64029145
# 0.63081026
# 0.53884774
# 0.60594386
# 0.5062659
# 0.5294854
# 0.5777638
# 0.62055075
# 0.5304446
# 0.5277339
# 0.54259336
# 0.5376865
# 0.5669512
# 0.582946
# 0.59813297
# 0.5034359
# 0.6383859
# 0.88992995
# 0.60707515
# 0.79868823
# 0.71352947
# 0.81462467
# 0.7082621
# 0.7064553
# 0.86728656
# 0.87930405
# 0.81696826
# 0.87192243
# 0.78321457
# 0.8346493
# 0.7809743
# 0.9267028
# 0.6971577
# 0.940425
# 0.9117249
# 0.6363508
# 0.7782715
# 0.77097154
# 0.90258753
# 0.7719421
# 0.8627095
# 0.94080764
# 0.92551255
# 0.9686781
# 0.9913366
# 0.9928746
# 0.99947935
# 0.9235646
# 0.9669822
# 0.74506307
# 0.98429996
# 0.8364183
# 0.8625341
# 0.5613974
# 0.5740728
# 0.60768366
# 0.55323404
# 0.5923994
# 0.67194116
# 0.73808634
# 0.50940526
# 0.58185095
# 0.5106028
# 0.51353586
# 0.5550295
# 0.5783671
# 0.61729896
# 0.64369553
# 0.50060385
# 0.5897321
# 0.60549104
# 0.54545236
# 0.672062
# 0.5082256
# 0.5595421
# 0.64765465
# 0.75258046
# 0.54770166
# 0.5479542
# 0.91660345
# 0.82294744
# 0.7246924
# 0.78369343
# 0.65710896
# 0.71689993
# 0.50149095
# 0.6031324
# 0.6041539
# 0.53964955
# 0.63993937
# 0.5679511
# 0.5329125
# 0.5333118
# 0.52078754
# 0.53235346
# 0.51060957
# 0.5964847
# 0.6215005
# 0.85172355
# 0.59937215
# 0.8522542
# 0.72012687
# 0.6001247
# 0.5385076
# 0.5474268
# 0.5227475
# 0.60274833
# 0.6095354
# 0.61336446
# 0.5312816
# 0.64536667
# 0.6100412
# 0.6242014
# 0.5584505
# 0.61644256
# 0.69129574
# 0.5243483
# 0.6249441
# 0.672198
# 0.58456886
# 0.52923024
# 0.585524
# 0.58667785
# 0.6075236
# 0.64247346
# 0.67231905
# 0.565178
# 0.5844761
# 0.515243
# 0.530712
# 0.609881
# 0.5147633
# 0.86875564
# 0.59835577
# 0.73109716
# 0.7686853
# 0.76133275
# 0.53137964
# 0.5689018
# 0.5685809
# 0.6333609
# 0.65229774
# 0.6902688
# 0.6065841
# 0.5716891
# 0.60997444
